# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('EDGARv8.0_FT2022_GHG_booklet_2023.csv',encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (212, 55)

# %%
df.head()
# Out:
#   EDGAR Country Code      Country      1970      1971      1972      1973  \
# 0                ABW        Aruba  0.764874  0.842243  1.017002  1.093028
# 1                AFG  Afghanistan  1.558155  1.514547  1.308854  1.327430
# 2                AGO       Angola  2.971847  2.889799  3.202473  3.349278
# 3                AIA     Anguilla  0.664745  0.659985  0.670368  0.640851
# 4                ALB      Albania  3.841370  3.726499  4.055711  3.744120
#
#        1974      1975      1976      1977  ...      2013      2014      2015  \
# 0  1.075665  1.304510  1.290385  1.472615  ...  4.495219  4.577104  4.566385
# 1  1.402300  1.428421  1.400988  1.389203  ...  0.973788  0.952880  0.925066
# 2  3.355909  3.109663  2.526316  3.028038  ...  3.191958  3.164378  3.234489
# 3  0.674738  0.707861  0.679611  0.692013  ...  2.319825  2.294322  2.280345
# 4  3.776578  3.779692  3.951595  4.088050  ...  2.917092  3.083604  3.025938
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 55 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EDGAR Country Code  210 non-null    object
#  1   Country             210 non-null    object
#  2   1970                210 non-null    float64
#  3   1971                210 non-null    float64
#  4   1972                210 non-null    float64
#  5   1973                210 non-null    float64
#  6   1974                210 non-null    float64
#  7   1975                210 non-null    float64
#  8   1976                210 non-null    float64
#  9   1977                210 non-null    float64
#  10  1978                210 non-null    float64
#  11  1979                210 non-null    float64
#  12  1980                210 non-null    float64
#  13  1981                210 non-null    float64
#  14  1982                210 non-null    float64
# ...

# %%
file_path = 'Final_Filtered_Merged_Temperature_and_GHG_Data.csv'
data = pd.read_csv(file_path)

# Filter the data for Japan
japan_data = data[data['Country'] == 'Singapore']

# Select relevant columns
japan_data = japan_data[['Year', 'Annual Mean', 'GHG']]

# Calculate the correlation coefficient
correlation_coefficient = japan_data['Annual Mean'].corr(japan_data['GHG'])

# Create a scatter plot with a regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(data=japan_data, x='Annual Mean', y='GHG')
sns.regplot(data=japan_data, x='Annual Mean', y='GHG', scatter=False, color='red')
plt.title(f'Correlation between Temperature and GHG Emissions in Niger relation Coefficient: {correlation_coefficient:.2f}')
plt.xlabel('Annual Mean Temperature (°C)')
plt.ylabel('GHG Emissions(MtCO2e)')
plt.grid(True)
plt.show()

# Print the correlation coefficient
print(f'Correlation Coefficient: {correlation_coefficient:.2f}')
# Out:
# Correlation Coefficient: 0.90

# %%
import pandas as pd

# Load the data from the CSV file
file_path = 'Final_Filtered_Merged_Temperature_and_GHG_Data.csv'
data = pd.read_csv(file_path)

# Group the data by country and calculate the correlation coefficient for each country
correlation_by_country = data.groupby('Country').apply(lambda x: x['Annual Mean'].corr(x['GHG']))

# Loop through all countries and print their correlation coefficients
for country, correlation in correlation_by_country.items():
    print(f"Country: {country}, Correlation Coefficient: {correlation}")
# Out:
# Country: Afghanistan, Correlation Coefficient: 0.5621225462305375
# Country: Albania, Correlation Coefficient: -0.3661379853943194
# Country: Algeria, Correlation Coefficient: 0.8119554254898429
# Country: Andorra, Correlation Coefficient: nan
# Country: Angola, Correlation Coefficient: 0.5555304601295292
# Country: Argentina, Correlation Coefficient: 0.5074723308734772
# Country: Armenia, Correlation Coefficient: -0.43374902314840713
# Country: Australia, Correlation Coefficient: 0.5140075835828393
# Country: Austria, Correlation Coefficient: 0.1695654285085545
# Country: Azerbaijan, Correlation Coefficient: -0.13429365437966576
# Country: Bahamas,, Correlation Coefficient: nan
# Country: Bahrain, Correlation Coefficient: 0.8584575127580439
# Country: Bangladesh, Correlation Coefficient: 0.238223332769989
# Country: Barbados, Correlation Coefficient: 0.7352733863245123
# Country: Belarus, Correlation Coefficient: -0.1945985282599283
# ...
